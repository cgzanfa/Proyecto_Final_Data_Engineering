# %% [markdown]
# <font color="#87CEEB" size="6">Carbon Intensity API</font>
#
# <font color="#4682B4" size="3">
# Introduction
# This is the Official Carbon Intensity API for Great Britain developed by National Energy System Operator (NESO). You can find out more about carbon intensity at carbonintensity.org.uk.
#
# Summary
# National Energy System Operator’s Carbon Intensity API provides an indicative trend of regional carbon intensity of the electricity system in Great Britain (GB) up to 2 days ahead of real-time. It provides programmatic and timely access to both forecast and estimated carbon intensity data. The Carbon Intensity forecast includes CO2 emissions related to electricity generation only. The includes emissions from all large metered power stations, interconnector imports, transmission and distribution losses, and accounts for national electricity demand, embedded wind and solar generation.</font>
#
#
# <font color="#4682B4" size="3">Base URL: <https://api.carbonintensity.org.uk/>

# %%
# @title
from IPython.display import HTML

html_code = """
<div style="background-color: lightpink; padding: 15px; border-radius: 5px; color: darkred;">
<strong><i>Módulo Nº1 - Unidad Nº 1</i></strong><br>
<br>
Extracción y almacenamiento de datos</div>
"""

display(HTML(html_code))
# Out:
# <div style="background-color: lightpink; padding: 15px; border-radius: 5px; color: darkred;">
# <strong><i>Módulo Nº1 - Unidad Nº 1</i></strong><br>
# <br>
# Extracción y almacenamiento de datos</div>

# %%
# !pip install requests
# !pip install deltalake
# !pip install pyarrow
# !pip install -q ydata-profiling
# Out:
# Requirement already satisfied: requests in c:\users\willy\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\willy\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\willy\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\willy\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\willy\anaconda3\lib\site-packages (from requests) (2025.1.31)
# Collecting deltalake
#   Downloading deltalake-0.25.5-cp39-abi3-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: pyarrow!=19.0.0,>=16 in c:\users\willy\anaconda3\lib\site-packages (from deltalake) (16.1.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\willy\anaconda3\lib\site-packages (from pyarrow!=19.0.0,>=16->deltalake) (1.26.4)
# Downloading deltalake-0.25.5-cp39-abi3-win_amd64.whl (38.2 MB)
#    ---------------------------------------- 0.0/38.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/38.2 MB 16.7 MB/s eta 0:00:03
#    -- ------------------------------------- 2.1/38.2 MB 7.8 MB/s eta 0:00:05
#    -- ------------------------------------- 2.1/38.2 MB 7.8 MB/s eta 0:00:05
#    --- ------------------------------------ 3.1/38.2 MB 3.5 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.2/38.2 MB 4.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.2/38.2 MB 4.4 MB/s eta 0:00:08
#    ------- -------------------------------- 7.3/38.2 MB 4.8 MB/s eta 0:00:07
#    -------- ------------------------------- 8.4/38.2 MB 5.0 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.5/38.2 MB 5.3 MB/s eta 0:00:06
#    ------------ --------------------------- 11.5/38.2 MB 5.4 MB/s eta 0:00:05
#    ------------ --------------------------- 11.5/38.2 MB 5.4 MB/s eta 0:00:05
#    ------------ --------------------------- 11.5/38.2 MB 5.4 MB/s eta 0:00:05
#    ------------- -------------------------- 12.6/38.2 MB 4.5 MB/s eta 0:00:06
#    -------------- ------------------------- 13.6/38.2 MB 4.6 MB/s eta 0:00:06
#    --------------- ------------------------ 14.7/38.2 MB 4.7 MB/s eta 0:00:06
#    ---------------- ----------------------- 15.7/38.2 MB 4.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 15.7/38.2 MB 4.8 MB/s eta 0:00:05
#    ----------------- ---------------------- 16.8/38.2 MB 4.3 MB/s eta 0:00:06
#    ------------------ --------------------- 17.8/38.2 MB 4.3 MB/s eta 0:00:05
#    ------------------- -------------------- 18.9/38.2 MB 4.4 MB/s eta 0:00:05
#    -------------------- ------------------- 19.9/38.2 MB 4.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.5/38.2 MB 4.5 MB/s eta 0:00:04
#    ------------------------ --------------- 23.1/38.2 MB 4.7 MB/s eta 0:00:04
#    ------------------------ --------------- 23.1/38.2 MB 4.7 MB/s eta 0:00:04
#    ------------------------ --------------- 23.1/38.2 MB 4.7 MB/s eta 0:00:04
#    -------------------------- ------------- 24.9/38.2 MB 4.4 MB/s eta 0:00:03
#    --------------------------- ------------ 26.2/38.2 MB 4.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.3/38.2 MB 4.6 MB/s eta 0:00:03
#    ------------------------------ --------- 29.4/38.2 MB 4.7 MB/s eta 0:00:02
#    ------------------------------- -------- 30.4/38.2 MB 4.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 32.5/38.2 MB 4.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.6/38.2 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.6/38.2 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.6/38.2 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.6/38.2 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 35.7/38.2 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.2 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.2 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.2/38.2 MB 4.5 MB/s eta 0:00:00
# Installing collected packages: deltalake
# Successfully installed deltalake-0.25.5
# Requirement already satisfied: pyarrow in c:\users\willy\anaconda3\lib\site-packages (16.1.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\willy\anaconda3\lib\site-packages (from pyarrow) (1.26.4)

# %%
# @title
from IPython.display import HTML

html_code = """
<div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
<strong>Delta Lake:</strong> es un formato de almacenamiento conocido como open table, o bien formato para lakehouse, que permite almacenar datos en un formato tabular, con la capacidad de realizar operaciones de lectura y escritura de datos
 de manera transaccional, es decir, que permite realizar operaciones de escritura y lectura de datos de manera atómica, lo que garantiza la integridad de los datos almacenados.</div>
"""

display(HTML(html_code))
# Out:
# <div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
# <strong>Delta Lake:</strong> es un formato de almacenamiento conocido como open table, o bien formato para lakehouse, que permite almacenar datos en un formato tabular, con la capacidad de realizar operaciones de lectura y escritura de datos
#  de manera transaccional, es decir, que permite realizar operaciones de escritura y lectura de datos de manera atómica, lo que garantiza la integridad de los datos almacenados.</div>

# %%
# Importamos las librerias y modulos necesarios
# write_deltalake: Modulo que permite escribir un DataFrame en un archivo Delta Lake
# DeltaTable: Modulo para manipular archivos Delta Lake

import json
import requests
import pandas as pd
import pyarrow as pa
from deltalake import write_deltalake, DeltaTable
from deltalake.exceptions import TableNotFoundError
from datetime import datetime, timedelta
import os
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
#Definimos una funcion para obtener datos de una API en formato .json
#Definimos una funcion que construye un DataFrame de pandas a partir de datos en formato JSON.

def get_data(base_url, endpoint, data_field=None, params=None, headers=None):
    """
    Realiza una solicitud GET a una API para obtener datos.

    Parámetros:
    base_url (str): La URL base de la API.
    endpoint (str): El endpoint de la API al que se realizará la solicitud.
    params (dict): Parámetros de consulta para enviar con la solicitud.
    data_field (str): El nombre del campo en el JSON que contiene los datos.
    headers (dict): Encabezados para enviar con la solicitud.

    Retorna:
    dict: Los datos obtenidos de la API en formato JSON.
    """
    try:
        endpoint_url = f"{base_url}/{endpoint}"
        response = requests.get(endpoint_url, params=params, headers=headers)
        response.raise_for_status()  # Levanta una excepción si hay un error en la respuesta HTTP.

        # Verificar si los datos están en formato JSON.
        try:
            data = response.json()
            if data_field:
              data = data[data_field]
        except:
            print("El formato de respuesta no es el esperado")
            return None
        return data

    except requests.exceptions.RequestException as e:
        # Capturar cualquier error de solicitud, como errores HTTP.
        print(f"La petición ha fallado. Código de error : {e}")
        return None

def build_table(json_data):
    """
    Construye un DataFrame de pandas a partir de datos en formato JSON.

    Parámetros:
    json_data (dict): Los datos en formato JSON obtenidos de una API.

    Retorna:
    DataFrame: Un DataFrame de pandas que contiene los datos.
    """
    try:
        df = pd.json_normalize(json_data)
        return df
    except:
        print("Los datos no están en el formato esperado")
        return None

# %%
#Definimos las funciones para realizar las actualizaciones
def save_data_as_delta(df, path, mode="overwrite", partition_cols=None):
    """
    Guarda un dataframe en formato Delta Lake en la ruta especificada.
    A su vez, es capaz de particionar el dataframe por una o varias columnas.
    Por defecto, el modo de guardado es "overwrite".

    Args:
      df (pd.DataFrame): El dataframe a guardar.
      path (str): La ruta donde se guardará el dataframe en formato Delta Lake.
      mode (str): El modo de guardado. Son los modos que soporta la libreria
      deltalake: "overwrite", "append", "error", "ignore".
      partition_cols (list or str): La/s columna/s por las que se particionará el
      dataframe. Si no se especifica, no se particionará.
    """
    write_deltalake(
        path, df, mode=mode, partition_by=partition_cols
    )

def save_new_data_as_delta(new_data, data_path, predicate, partition_cols=None):
    """
    Guarda solo nuevos datos en formato Delta Lake usando la operación MERGE,
    comparando los datos ya cargados con los datos que se desean almacenar
    asegurando que no se guarden registros duplicados.

    Args:
      new_data (pd.DataFrame): Los datos que se desean guardar.
      data_path (str): La ruta donde se guardará el dataframe en formato Delta Lake.
      predicate (str): La condición de predicado para la operación MERGE.
    """

    try:
      dt = DeltaTable(data_path)
      new_data_pa = pa.Table.from_pandas(new_data)
      # Se insertan en target, datos de source que no existen en target
      dt.merge(
          source=new_data_pa,
          source_alias="source",
          target_alias="target",
          predicate=predicate
      ) \
      .when_not_matched_insert_all() \
      .execute()

    # Si no existe la tabla Delta Lake, se guarda como nueva
    except TableNotFoundError:
      save_data_as_delta(new_data, data_path, partition_cols=partition_cols)



def upsert_data_as_delta(data, data_path, predicate):
    """
    Guardar datos en formato Delta Lake usando la operacion MERGE.
    Cuando no haya registros coincidentes, se insertarán nuevos registros.
    Cuando haya registros coincidentes, se actualizarán los campos.

    Args:
      data (pd.DataFrame): Los datos que se desean guardar.
      data_path (str): La ruta donde se guardará el dataframe en formato Delta Lake.
      predicate (str): La condición de predicado para la operación MERGE.
    """
    try:
        dt = DeltaTable(data_path)
        data_pa = pa.Table.from_pandas(data)
        dt.merge(
            source=data_pa,
            source_alias="source",
            target_alias="target",
            predicate=predicate
        ) \
        .when_matched_update_all() \
        .when_not_matched_insert_all() \
        .execute()
    except TableNotFoundError:
        save_data_as_delta(data, data_path)



def read_most_recent_partition(data_path):
    """
    Lee la particion mas reciente de una tabla Delta Lake, teniendo en cuenta
    la fecha y hora actual.
    Supone que la tabla delta lake esta particionada por fecha y hora

    Args:
      data_path (str): La ruta donde se encuentra la tabla Delta Lake.

    Returns:
      pd.DataFrame: Los datos de la particion mas reciente.
    """
    try:
      requested_date = datetime.utcnow() - timedelta(hours=1)
      dt = DeltaTable(data_path)
      df_recent = dt.to_pandas(
        partitions=[
        ("fecha", "=", requested_date.strftime("%Y-%m-%d")),
        ("hora", "=", requested_date.strftime("%H"))
        ]
        )
      return df_recent
    except:
      raise Exception(f"No se pudo procesar la tabla Delta Lake, por {E}")
      return None

# %%
# @title
from IPython.display import HTML

html_code = """
<div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
<strong>Extraccion full:</strong> se caracteriza por extraer todos los datos de la fuente en cada ejecución del
proceso de extracción y volcarlos por completo en el sistema de destino. El
volcado de los datos puede sobreescribir lo que ya está disponible en el
sistema de destino, o depositar los datos en otro archivo o directorio. Puede ser
útil cuando se trabaja con fuentes de datos estáticas o cuando los requisitos del
proyecto no permiten la identificación de cambios incrementales.</div>
"""

display(HTML(html_code))
# Out:
# <div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
# <strong>Extraccion full:</strong> se caracteriza por extraer todos los datos de la fuente en cada ejecución del
# proceso de extracción y volcarlos por completo en el sistema de destino. El
# volcado de los datos puede sobreescribir lo que ya está disponible en el
# sistema de destino, o depositar los datos en otro archivo o directorio. Puede ser
# útil cuando se trabaja con fuentes de datos estáticas o cuando los requisitos del
# proyecto no permiten la identificación de cambios incrementales.</div>

# %%
##############################################################
#                      EXTRACCION FULL                       #
##############################################################



#Creamos una variable con la URL base que vamos a trabajar
base_url = "https://api.carbonintensity.org.uk/"



#Definimos el "endpoint" con el que vamos a trabajar y del cual tenemos que extraer la informacion, para hacerlo debemos suministrar
#los siguientes parametros:

##############################################################
#Segun la pagina web debemos suministar los siguientes datos:#
##############################################################

# GET /regional/intensity/{from}/fw48h/postcode/{postcode}
# Code samples

# # You can also use wget
# curl -X GET https://api.carbonintensity.org.uk/regional/intensity/{from}/fw48h/postcode/{postcode} \
#   -H 'Accept: application/json'

# Get Carbon Intensity data for next 48h for specified postcode

# Get Regional Carbon Intensity data for next 48h for specified postcode. All times provided in UTC (+00:00).



#Definimos una variable de inicio que tome el ultimo año
start_date_full = datetime.utcnow() - timedelta(days=365)

#Le damos formato para que tome la medicion del 1er dia de cada mes del año anterior
start_date_full = start_date_full.strftime("%Y-%m-01T00:00:00Z")


#Definimos el codigo postal como parametro
postcode = "RG10"

endpoint_regional = f"/regional/intensity/{start_date_full}/fw48h/postcode/{postcode}"

regional_json_data = get_data(base_url, endpoint_regional, data_field='data')

print(start_date_full)
regional_json_data
# Out:
# C:\Users\Willy\AppData\Local\Temp\ipykernel_13792\2385471426.py:33: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start_date_full = datetime.utcnow() - timedelta(days=365)
# 2024-05-01T00:00:00Z
# {'regionid': 12,
#  'dnoregion': 'SSE South',
#  'shortname': 'South England',
#  'postcode': 'RG10',
#  'data': [{'from': '2024-04-30T23:30Z',
#    'to': '2024-05-01T00:00Z',
#    'intensity': {'forecast': 156, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7.7},
#     {'fuel': 'coal', 'perc': 1.5},
#     {'fuel': 'imports', 'perc': 52.7},
#     {'fuel': 'gas', 'perc': 31.9},
#     {'fuel': 'nuclear', 'perc': 0.7},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 5.3}]},
#   {'from': '2024-05-01T00:00Z',
#    'to': '2024-05-01T00:30Z',
#    'intensity': {'forecast': 174, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7.5},
#     {'fuel': 'coal', 'perc': 1.1},
#     {'fuel': 'imports', 'perc': 47.7},
#     {'fuel': 'gas', 'perc': 37.7},
#     {'fuel': 'nuclear', 'perc': 0.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 5.1}]},
#   {'from': '2024-05-01T00:30Z',
#    'to': '2024-05-01T01:00Z',
#    'intensity': {'forecast': 162, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7.7},
#     {'fuel': 'coal', 'perc': 1.2},
#     {'fuel': 'imports', 'perc': 50.2},
#     {'fuel': 'gas', 'perc': 34.1},
#     {'fuel': 'nuclear', 'perc': 1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 5.7}]},
#   {'from': '2024-05-01T01:00Z',
#    'to': '2024-05-01T01:30Z',
#    'intensity': {'forecast': 157, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 8.8},
#     {'fuel': 'coal', 'perc': 1.4},
#     {'fuel': 'imports', 'perc': 50.8},
#     {'fuel': 'gas', 'perc': 32},
#     {'fuel': 'nuclear', 'perc': 1.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 5.6}]},
#   {'from': '2024-05-01T01:30Z',
#    'to': '2024-05-01T02:00Z',
#    'intensity': {'forecast': 159, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 12.2},
#     {'fuel': 'coal', 'perc': 1.6},
#     {'fuel': 'imports', 'perc': 46.6},
#     {'fuel': 'gas', 'perc': 31.8},
#     {'fuel': 'nuclear', 'perc': 1.4},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 6.4}]},
#   {'from': '2024-05-01T02:00Z',
#    'to': '2024-05-01T02:30Z',
#    'intensity': {'forecast': 157, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 12.5},
#     {'fuel': 'coal', 'perc': 1.6},
#     {'fuel': 'imports', 'perc': 47.2},
#     {'fuel': 'gas', 'perc': 31.3},
#     {'fuel': 'nuclear', 'perc': 1.4},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 6}]},
#   {'from': '2024-05-01T02:30Z',
#    'to': '2024-05-01T03:00Z',
#    'intensity': {'forecast': 168, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 11.5},
#     {'fuel': 'coal', 'perc': 1.6},
#     {'fuel': 'imports', 'perc': 46.6},
#     {'fuel': 'gas', 'perc': 34.4},
#     {'fuel': 'nuclear', 'perc': 1.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 4.5}]},
#   {'from': '2024-05-01T03:00Z',
#    'to': '2024-05-01T03:30Z',
#    'intensity': {'forecast': 161, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 12.6},
#     {'fuel': 'coal', 'perc': 1.5},
#     {'fuel': 'imports', 'perc': 47.2},
#     {'fuel': 'gas', 'perc': 32.5},
#     {'fuel': 'nuclear', 'perc': 1.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 4.9}]},
#   {'from': '2024-05-01T03:30Z',
#    'to': '2024-05-01T04:00Z',
#    'intensity': {'forecast': 166, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 9.1},
#     {'fuel': 'coal', 'perc': 1.2},
#     {'fuel': 'imports', 'perc': 50.1},
#     {'fuel': 'gas', 'perc': 35},
#     {'fuel': 'nuclear', 'perc': 0.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 3.5}]},
#   {'from': '2024-05-01T04:00Z',
#    'to': '2024-05-01T04:30Z',
#    'intensity': {'forecast': 181, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7.7},
#     {'fuel': 'coal', 'perc': 1.1},
#     {'fuel': 'imports', 'perc': 47.7},
#     {'fuel': 'gas', 'perc': 39.6},
#     {'fuel': 'nuclear', 'perc': 0.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.4},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 2.9}]},
#   {'from': '2024-05-01T04:30Z',
#    'to': '2024-05-01T05:00Z',
#    'intensity': {'forecast': 194, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6.2},
#     {'fuel': 'coal', 'perc': 0.9},
#     {'fuel': 'imports', 'perc': 46.4},
#     {'fuel': 'gas', 'perc': 43.7},
#     {'fuel': 'nuclear', 'perc': 0.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.6},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 1.9}]},
#   {'from': '2024-05-01T05:00Z',
#    'to': '2024-05-01T05:30Z',
#    'intensity': {'forecast': 214, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.1},
#     {'fuel': 'coal', 'perc': 0.6},
#     {'fuel': 'imports', 'perc': 42.3},
#     {'fuel': 'gas', 'perc': 50.4},
#     {'fuel': 'nuclear', 'perc': 0.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.5},
#     {'fuel': 'solar', 'perc': 0.6},
#     {'fuel': 'wind', 'perc': 1.3}]},
#   {'from': '2024-05-01T05:30Z',
#    'to': '2024-05-01T06:00Z',
#    'intensity': {'forecast': 225, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 1.4},
#     {'fuel': 'coal', 'perc': 0.5},
#     {'fuel': 'imports', 'perc': 40.8},
#     {'fuel': 'gas', 'perc': 54.1},
#     {'fuel': 'nuclear', 'perc': 0.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.7},
#     {'fuel': 'solar', 'perc': 1.8},
#     {'fuel': 'wind', 'perc': 0.6}]},
#   {'from': '2024-05-01T06:00Z',
#    'to': '2024-05-01T06:30Z',
#    'intensity': {'forecast': 215, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 1.3},
#     {'fuel': 'coal', 'perc': 0.3},
#     {'fuel': 'imports', 'perc': 41.3},
#     {'fuel': 'gas', 'perc': 51.7},
#     {'fuel': 'nuclear', 'perc': 0.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1.1},
#     {'fuel': 'solar', 'perc': 3.5},
#     {'fuel': 'wind', 'perc': 0.6}]},
#   {'from': '2024-05-01T06:30Z',
#    'to': '2024-05-01T07:00Z',
#    'intensity': {'forecast': 205, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0.4},
#     {'fuel': 'coal', 'perc': 0.3},
#     {'fuel': 'imports', 'perc': 42.4},
#     {'fuel': 'gas', 'perc': 49.4},
#     {'fuel': 'nuclear', 'perc': 0.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1.2},
#     {'fuel': 'solar', 'perc': 5.7},
#     {'fuel': 'wind', 'perc': 0.4}]},
#   {'from': '2024-05-01T07:00Z',
#    'to': '2024-05-01T07:30Z',
#    'intensity': {'forecast': 188, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0.4},
#     {'fuel': 'coal', 'perc': 0.1},
#     {'fuel': 'imports', 'perc': 42.9},
#     {'fuel': 'gas', 'perc': 45.5},
#     {'fuel': 'nuclear', 'perc': 0.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1.1},
#     {'fuel': 'solar', 'perc': 9.3},
#     {'fuel': 'wind', 'perc': 0.5}]},
#   {'from': '2024-05-01T07:30Z',
#    'to': '2024-05-01T08:00Z',
#    'intensity': {'forecast': 174, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 42.3},
#     {'fuel': 'gas', 'perc': 42.5},
#     {'fuel': 'nuclear', 'perc': 0.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1},
#     {'fuel': 'solar', 'perc': 13.6},
#     {'fuel': 'wind', 'perc': 0.5}]},
#   {'from': '2024-05-01T08:00Z',
#    'to': '2024-05-01T08:30Z',
#    'intensity': {'forecast': 163, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 42.1},
#     {'fuel': 'gas', 'perc': 39.7},
#     {'fuel': 'nuclear', 'perc': 0},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.9},
#     {'fuel': 'solar', 'perc': 16.7},
#     {'fuel': 'wind', 'perc': 0.5}]},
#   {'from': '2024-05-01T08:30Z',
#    'to': '2024-05-01T09:00Z',
#    'intensity': {'forecast': 158, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 40},
#     {'fuel': 'gas', 'perc': 38.5},
#     {'fuel': 'nuclear', 'perc': 0},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.8},
#     {'fuel': 'solar', 'perc': 20.2},
#     {'fuel': 'wind', 'perc': 0.6}]},
#   {'from': '2024-05-01T09:00Z',
#    'to': '2024-05-01T09:30Z',
#    'intensity': {'forecast': 150, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 36.7},
#     {'fuel': 'gas', 'perc': 36.8},
#     {'fuel': 'nuclear', 'perc': 0},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.6},
#     {'fuel': 'solar', 'perc': 25.2},
#     {'fuel': 'wind', 'perc': 0.6}]},
#   {'from': '2024-05-01T09:30Z',
#    'to': '2024-05-01T10:00Z',
#    'intensity': {'forecast': 157, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 35.5},
#     {'fuel': 'gas', 'perc': 34.2},
#     {'fuel': 'nuclear', 'perc': 0},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.4},
#     {'fuel': 'solar', 'perc': 29.2},
#     {'fuel': 'wind', 'perc': 0.7}]},
#   {'from': '2024-05-01T10:00Z',
#    'to': '2024-05-01T10:30Z',
#    'intensity': {'forecast': 166, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 35.4},
#     {'fuel': 'gas', 'perc': 36.4},
#     {'fuel': 'nuclear', 'perc': 0},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 27.3},
#     {'fuel': 'wind', 'perc': 0.7}]},
#   {'from': '2024-05-01T10:30Z',
#    'to': '2024-05-01T11:00Z',
#    'intensity': {'forecast': 163, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 36.6},
#     {'fuel': 'gas', 'perc': 35.5},
#     {'fuel': 'nuclear', 'perc': 0},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 27},
#     {'fuel': 'wind', 'perc': 0.7}]},
#   {'from': '2024-05-01T11:00Z',
#    'to': '2024-05-01T11:30Z',
#    'intensity': {'forecast': 159, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 38.1},
#     {'fuel': 'gas', 'perc': 34.2},
#     {'fuel': 'nuclear', 'perc': 0},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 26.9},
#     {'fuel': 'wind', 'perc': 0.7}]},
#   {'from': '2024-05-01T11:30Z',
#    'to': '2024-05-01T12:00Z',
#    'intensity': {'forecast': 159, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 38.9},
#     {'fuel': 'gas', 'perc': 34},
#     {'fuel': 'nuclear', 'perc': 0},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 26.3},
#     {'fuel': 'wind', 'perc': 0.7}]},
#   {'from': '2024-05-01T12:00Z',
#    'to': '2024-05-01T12:30Z',
#    'intensity': {'forecast': 168, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 38.2},
#     {'fuel': 'gas', 'perc': 36.3},
#     {'fuel': 'nuclear', 'perc': 0.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 24.4},
#     {'fuel': 'wind', 'perc': 0.8}]},
#   {'from': '2024-05-01T12:30Z',
#    'to': '2024-05-01T13:00Z',
#    'intensity': {'forecast': 169, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 38.6},
#     {'fuel': 'gas', 'perc': 36.5},
#     {'fuel': 'nuclear', 'perc': 0.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 23.9},
#     {'fuel': 'wind', 'perc': 0.8}]},
#   {'from': '2024-05-01T13:00Z',
#    'to': '2024-05-01T13:30Z',
#    'intensity': {'forecast': 181, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 39},
#     {'fuel': 'gas', 'perc': 39.5},
#     {'fuel': 'nuclear', 'perc': 0.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 20.5},
#     {'fuel': 'wind', 'perc': 0.7}]},
#   {'from': '2024-05-01T13:30Z',
#    'to': '2024-05-01T14:00Z',
#    'intensity': {'forecast': 195, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 39.6},
#     {'fuel': 'gas', 'perc': 43},
#     {'fuel': 'nuclear', 'perc': 0.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 16.1},
#     {'fuel': 'wind', 'perc': 0.9}]},
#   {'from': '2024-05-01T14:00Z',
#    'to': '2024-05-01T14:30Z',
#    'intensity': {'forecast': 205, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 39.5},
#     {'fuel': 'gas', 'perc': 45.5},
#     {'fuel': 'nuclear', 'perc': 0.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.5},
#     {'fuel': 'solar', 'perc': 13.2},
#     {'fuel': 'wind', 'perc': 1.2}]},
#   {'from': '2024-05-01T14:30Z',
#    'to': '2024-05-01T15:00Z',
#    'intensity': {'forecast': 207, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 39.9},
#     {'fuel': 'gas', 'perc': 45.8},
#     {'fuel': 'nuclear', 'perc': 0.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.8},
#     {'fuel': 'solar', 'perc': 11.9},
#     {'fuel': 'wind', 'perc': 1.4}]},
#   {'from': '2024-05-01T15:00Z',
#    'to': '2024-05-01T15:30Z',
#    'intensity': {'forecast': 212, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 40.3},
#     {'fuel': 'gas', 'perc': 46.8},
#     {'fuel': 'nuclear', 'perc': 0.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.9},
#     {'fuel': 'solar', 'perc': 10.3},
#     {'fuel': 'wind', 'perc': 1.5}]},
#   {'from': '2024-05-01T15:30Z',
#    'to': '2024-05-01T16:00Z',
#    'intensity': {'forecast': 214, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 41.4},
#     {'fuel': 'gas', 'perc': 47.3},
#     {'fuel': 'nuclear', 'perc': 0.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1},
#     {'fuel': 'solar', 'perc': 8.5},
#     {'fuel': 'wind', 'perc': 1.6}]},
#   {'from': '2024-05-01T16:00Z',
#    'to': '2024-05-01T16:30Z',
#    'intensity': {'forecast': 220, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 0.2},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 41.2},
#     {'fuel': 'gas', 'perc': 48.7},
#     {'fuel': 'nuclear', 'perc': 0.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.9},
#     {'fuel': 'solar', 'perc': 6.6},
#     {'fuel': 'wind', 'perc': 2.1}]},
#   {'from': '2024-05-01T16:30Z',
#    'to': '2024-05-01T17:00Z',
#    'intensity': {'forecast': 223, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 1.7},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 39.4},
#     {'fuel': 'gas', 'perc': 49.6},
#     {'fuel': 'nuclear', 'perc': 0.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.9},
#     {'fuel': 'solar', 'perc': 5.1},
#     {'fuel': 'wind', 'perc': 3}]},
#   {'from': '2024-05-01T17:00Z',
#    'to': '2024-05-01T17:30Z',
#    'intensity': {'forecast': 218, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 3.9},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 38.2},
#     {'fuel': 'gas', 'perc': 48.4},
#     {'fuel': 'nuclear', 'perc': 0.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1},
#     {'fuel': 'solar', 'perc': 4.4},
#     {'fuel': 'wind', 'perc': 3.8}]},
#   {'from': '2024-05-01T17:30Z',
#    'to': '2024-05-01T18:00Z',
#    'intensity': {'forecast': 213, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.2},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 40.4},
#     {'fuel': 'gas', 'perc': 46.4},
#     {'fuel': 'nuclear', 'perc': 0.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1},
#     {'fuel': 'solar', 'perc': 3.1},
#     {'fuel': 'wind', 'perc': 4.5}]},
#   {'from': '2024-05-01T18:00Z',
#    'to': '2024-05-01T18:30Z',
#    'intensity': {'forecast': 220, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 3.9},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 40.7},
#     {'fuel': 'gas', 'perc': 48},
#     {'fuel': 'nuclear', 'perc': 0.4},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1},
#     {'fuel': 'solar', 'perc': 1.8},
#     {'fuel': 'wind', 'perc': 4.4}]},
#   {'from': '2024-05-01T18:30Z',
#    'to': '2024-05-01T19:00Z',
#    'intensity': {'forecast': 222, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 3.8},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 40.8},
#     {'fuel': 'gas', 'perc': 48.5},
#     {'fuel': 'nuclear', 'perc': 0.5},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.9},
#     {'fuel': 'solar', 'perc': 0.7},
#     {'fuel': 'wind', 'perc': 4.8}]},
#   {'from': '2024-05-01T19:00Z',
#    'to': '2024-05-01T19:30Z',
#    'intensity': {'forecast': 223, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 3.7},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 40.2},
#     {'fuel': 'gas', 'perc': 49},
#     {'fuel': 'nuclear', 'perc': 0.5},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.8},
#     {'fuel': 'solar', 'perc': 0.1},
#     {'fuel': 'wind', 'perc': 5.6}]},
#   {'from': '2024-05-01T19:30Z',
#    'to': '2024-05-01T20:00Z',
#    'intensity': {'forecast': 212, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 3.1},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 43.9},
#     {'fuel': 'gas', 'perc': 45.7},
#     {'fuel': 'nuclear', 'perc': 0.5},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.6},
#     {'fuel': 'solar', 'perc': 0.1},
#     {'fuel': 'wind', 'perc': 6}]},
#   {'from': '2024-05-01T20:00Z',
#    'to': '2024-05-01T20:30Z',
#    'intensity': {'forecast': 210, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 3.3},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 43.5},
#     {'fuel': 'gas', 'perc': 45.3},
#     {'fuel': 'nuclear', 'perc': 0.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.4},
#     {'fuel': 'solar', 'perc': 0.1},
#     {'fuel': 'wind', 'perc': 6.9}]},
#   {'from': '2024-05-01T20:30Z',
#    'to': '2024-05-01T21:00Z',
#    'intensity': {'forecast': 204, 'index': 'high'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 3.1},
#     {'fuel': 'coal', 'perc': 0.1},
#     {'fuel': 'imports', 'perc': 45.4},
#     {'fuel': 'gas', 'perc': 43.2},
#     {'fuel': 'nuclear', 'perc': 0.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 7.1}]},
#   {'from': '2024-05-01T21:00Z',
#    'to': '2024-05-01T21:30Z',
#    'intensity': {'forecast': 178, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 2.4},
#     {'fuel': 'coal', 'perc': 0.3},
#     {'fuel': 'imports', 'perc': 50.8},
#     {'fuel': 'gas', 'perc': 35.2},
#     {'fuel': 'nuclear', 'perc': 1.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0.1},
#     {'fuel': 'wind', 'perc': 9.7}]},
#   {'from': '2024-05-01T21:30Z',
#    'to': '2024-05-01T22:00Z',
#    'intensity': {'forecast': 149, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 1.1},
#     {'fuel': 'coal', 'perc': 0.6},
#     {'fuel': 'imports', 'perc': 58.2},
#     {'fuel': 'gas', 'perc': 25.7},
#     {'fuel': 'nuclear', 'perc': 1.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 12.2}]},
#   {'from': '2024-05-01T22:00Z',
#    'to': '2024-05-01T22:30Z',
#    'intensity': {'forecast': 136, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 2.3},
#     {'fuel': 'coal', 'perc': 1},
#     {'fuel': 'imports', 'perc': 57.2},
#     {'fuel': 'gas', 'perc': 21.4},
#     {'fuel': 'nuclear', 'perc': 2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 16}]},
#   {'from': '2024-05-01T22:30Z',
#    'to': '2024-05-01T23:00Z',
#    'intensity': {'forecast': 143, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 3.4},
#     {'fuel': 'coal', 'perc': 1.2},
#     {'fuel': 'imports', 'perc': 49.4},
#     {'fuel': 'gas', 'perc': 25},
#     {'fuel': 'nuclear', 'perc': 1.9},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 18.9}]},
#   {'from': '2024-05-01T23:00Z',
#    'to': '2024-05-01T23:30Z',
#    'intensity': {'forecast': 139, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.1},
#     {'fuel': 'coal', 'perc': 1.5},
#     {'fuel': 'imports', 'perc': 50.4},
#     {'fuel': 'gas', 'perc': 23},
#     {'fuel': 'nuclear', 'perc': 2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 18.7}]},
#   {'from': '2024-05-01T23:30Z',
#    'to': '2024-05-02T00:00Z',
#    'intensity': {'forecast': 144, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.3},
#     {'fuel': 'coal', 'perc': 1.7},
#     {'fuel': 'imports', 'perc': 47.7},
#     {'fuel': 'gas', 'perc': 24.1},
#     {'fuel': 'nuclear', 'perc': 1.7},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 19.5}]},
#   {'from': '2024-05-02T00:00Z',
#    'to': '2024-05-02T00:30Z',
#    'intensity': {'forecast': 142, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.4},
#     {'fuel': 'coal', 'perc': 1.5},
#     {'fuel': 'imports', 'perc': 46.9},
#     {'fuel': 'gas', 'perc': 24.2},
#     {'fuel': 'nuclear', 'perc': 1.7},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0.1},
#     {'fuel': 'wind', 'perc': 20.1}]},
#   {'from': '2024-05-02T00:30Z',
#    'to': '2024-05-02T01:00Z',
#    'intensity': {'forecast': 142, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.8},
#     {'fuel': 'coal', 'perc': 1.5},
#     {'fuel': 'imports', 'perc': 50.8},
#     {'fuel': 'gas', 'perc': 23.6},
#     {'fuel': 'nuclear', 'perc': 1.7},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 17.5}]},
#   {'from': '2024-05-02T01:00Z',
#    'to': '2024-05-02T01:30Z',
#    'intensity': {'forecast': 143, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.4},
#     {'fuel': 'coal', 'perc': 1.5},
#     {'fuel': 'imports', 'perc': 49},
#     {'fuel': 'gas', 'perc': 24.8},
#     {'fuel': 'nuclear', 'perc': 1.9},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 18.4}]},
#   {'from': '2024-05-02T01:30Z',
#    'to': '2024-05-02T02:00Z',
#    'intensity': {'forecast': 142, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.1},
#     {'fuel': 'coal', 'perc': 1.6},
#     {'fuel': 'imports', 'perc': 50.8},
#     {'fuel': 'gas', 'perc': 24.3},
#     {'fuel': 'nuclear', 'perc': 2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 17.2}]},
#   {'from': '2024-05-02T02:00Z',
#    'to': '2024-05-02T02:30Z',
#    'intensity': {'forecast': 143, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.4},
#     {'fuel': 'coal', 'perc': 1.6},
#     {'fuel': 'imports', 'perc': 51.5},
#     {'fuel': 'gas', 'perc': 24.2},
#     {'fuel': 'nuclear', 'perc': 2.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 16}]},
#   {'from': '2024-05-02T02:30Z',
#    'to': '2024-05-02T03:00Z',
#    'intensity': {'forecast': 145, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.2},
#     {'fuel': 'coal', 'perc': 1.7},
#     {'fuel': 'imports', 'perc': 50.7},
#     {'fuel': 'gas', 'perc': 24.5},
#     {'fuel': 'nuclear', 'perc': 2.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 15.7}]},
#   {'from': '2024-05-02T03:00Z',
#    'to': '2024-05-02T03:30Z',
#    'intensity': {'forecast': 143, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6.1},
#     {'fuel': 'coal', 'perc': 2.1},
#     {'fuel': 'imports', 'perc': 51.5},
#     {'fuel': 'gas', 'perc': 22.9},
#     {'fuel': 'nuclear', 'perc': 1.9},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 15.5}]},
#   {'from': '2024-05-02T03:30Z',
#    'to': '2024-05-02T04:00Z',
#    'intensity': {'forecast': 152, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.2},
#     {'fuel': 'coal', 'perc': 1.9},
#     {'fuel': 'imports', 'perc': 51.9},
#     {'fuel': 'gas', 'perc': 25.4},
#     {'fuel': 'nuclear', 'perc': 1.5},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 14}]},
#   {'from': '2024-05-02T04:00Z',
#    'to': '2024-05-02T04:30Z',
#    'intensity': {'forecast': 151, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.3},
#     {'fuel': 'coal', 'perc': 1.5},
#     {'fuel': 'imports', 'perc': 52.8},
#     {'fuel': 'gas', 'perc': 25.7},
#     {'fuel': 'nuclear', 'perc': 1.4},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 13.2}]},
#   {'from': '2024-05-02T04:30Z',
#    'to': '2024-05-02T05:00Z',
#    'intensity': {'forecast': 149, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.7},
#     {'fuel': 'coal', 'perc': 1.4},
#     {'fuel': 'imports', 'perc': 55.6},
#     {'fuel': 'gas', 'perc': 24},
#     {'fuel': 'nuclear', 'perc': 1.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 12.8}]},
#   {'from': '2024-05-02T05:00Z',
#    'to': '2024-05-02T05:30Z',
#    'intensity': {'forecast': 152, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6.9},
#     {'fuel': 'coal', 'perc': 1.3},
#     {'fuel': 'imports', 'perc': 51},
#     {'fuel': 'gas', 'perc': 25.6},
#     {'fuel': 'nuclear', 'perc': 1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.4},
#     {'fuel': 'solar', 'perc': 0.6},
#     {'fuel': 'wind', 'perc': 13.2}]},
#   {'from': '2024-05-02T05:30Z',
#    'to': '2024-05-02T06:00Z',
#    'intensity': {'forecast': 156, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6.4},
#     {'fuel': 'coal', 'perc': 1},
#     {'fuel': 'imports', 'perc': 51.7},
#     {'fuel': 'gas', 'perc': 26.8},
#     {'fuel': 'nuclear', 'perc': 0.7},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.6},
#     {'fuel': 'solar', 'perc': 1.6},
#     {'fuel': 'wind', 'perc': 11.2}]},
#   {'from': '2024-05-02T06:00Z',
#    'to': '2024-05-02T06:30Z',
#    'intensity': {'forecast': 151, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6},
#     {'fuel': 'coal', 'perc': 0.4},
#     {'fuel': 'imports', 'perc': 51.2},
#     {'fuel': 'gas', 'perc': 27.3},
#     {'fuel': 'nuclear', 'perc': 0.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.9},
#     {'fuel': 'solar', 'perc': 3.2},
#     {'fuel': 'wind', 'perc': 10.4}]},
#   {'from': '2024-05-02T06:30Z',
#    'to': '2024-05-02T07:00Z',
#    'intensity': {'forecast': 147, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 50.9},
#     {'fuel': 'gas', 'perc': 27.2},
#     {'fuel': 'nuclear', 'perc': 0.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1.1},
#     {'fuel': 'solar', 'perc': 5},
#     {'fuel': 'wind', 'perc': 9.1}]},
#   {'from': '2024-05-02T07:00Z',
#    'to': '2024-05-02T07:30Z',
#    'intensity': {'forecast': 157, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.9},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 49.1},
#     {'fuel': 'gas', 'perc': 30.4},
#     {'fuel': 'nuclear', 'perc': 0.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1.1},
#     {'fuel': 'solar', 'perc': 6.1},
#     {'fuel': 'wind', 'perc': 7.7}]},
#   {'from': '2024-05-02T07:30Z',
#    'to': '2024-05-02T08:00Z',
#    'intensity': {'forecast': 153, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.9},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 47.8},
#     {'fuel': 'gas', 'perc': 29.6},
#     {'fuel': 'nuclear', 'perc': 0.7},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 1},
#     {'fuel': 'solar', 'perc': 8.1},
#     {'fuel': 'wind', 'perc': 7.8}]},
#   {'from': '2024-05-02T08:00Z',
#    'to': '2024-05-02T08:30Z',
#    'intensity': {'forecast': 141, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.3},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 47.7},
#     {'fuel': 'gas', 'perc': 26.5},
#     {'fuel': 'nuclear', 'perc': 0.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.6},
#     {'fuel': 'solar', 'perc': 10.2},
#     {'fuel': 'wind', 'perc': 8.8}]},
#   {'from': '2024-05-02T08:30Z',
#    'to': '2024-05-02T09:00Z',
#    'intensity': {'forecast': 128, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.8},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 46.7},
#     {'fuel': 'gas', 'perc': 23.3},
#     {'fuel': 'nuclear', 'perc': 0.9},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 13},
#     {'fuel': 'wind', 'perc': 10.1}]},
#   {'from': '2024-05-02T09:00Z',
#    'to': '2024-05-02T09:30Z',
#    'intensity': {'forecast': 110, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6.2},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 46.9},
#     {'fuel': 'gas', 'perc': 18.6},
#     {'fuel': 'nuclear', 'perc': 1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 16.3},
#     {'fuel': 'wind', 'perc': 10.9}]},
#   {'from': '2024-05-02T09:30Z',
#    'to': '2024-05-02T10:00Z',
#    'intensity': {'forecast': 102, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.5},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 46.7},
#     {'fuel': 'gas', 'perc': 16.8},
#     {'fuel': 'nuclear', 'perc': 1.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 19.1},
#     {'fuel': 'wind', 'perc': 10.6}]},
#   {'from': '2024-05-02T10:00Z',
#    'to': '2024-05-02T10:30Z',
#    'intensity': {'forecast': 96, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.2},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 46.9},
#     {'fuel': 'gas', 'perc': 15.4},
#     {'fuel': 'nuclear', 'perc': 1.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 20.9},
#     {'fuel': 'wind', 'perc': 10.1}]},
#   {'from': '2024-05-02T10:30Z',
#    'to': '2024-05-02T11:00Z',
#    'intensity': {'forecast': 87, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.7},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 46.5},
#     {'fuel': 'gas', 'perc': 13},
#     {'fuel': 'nuclear', 'perc': 1.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 23},
#     {'fuel': 'wind', 'perc': 10.4}]},
#   {'from': '2024-05-02T11:00Z',
#    'to': '2024-05-02T11:30Z',
#    'intensity': {'forecast': 63, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.5},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 44.9},
#     {'fuel': 'gas', 'perc': 13},
#     {'fuel': 'nuclear', 'perc': 1.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 24.2},
#     {'fuel': 'wind', 'perc': 10.7}]},
#   {'from': '2024-05-02T11:30Z',
#    'to': '2024-05-02T12:00Z',
#    'intensity': {'forecast': 64, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.4},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 45.6},
#     {'fuel': 'gas', 'perc': 13.4},
#     {'fuel': 'nuclear', 'perc': 2.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 24.7},
#     {'fuel': 'wind', 'perc': 9.5}]},
#   {'from': '2024-05-02T12:00Z',
#    'to': '2024-05-02T12:30Z',
#    'intensity': {'forecast': 62, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.5},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 44.5},
#     {'fuel': 'gas', 'perc': 12.9},
#     {'fuel': 'nuclear', 'perc': 2.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 25.2},
#     {'fuel': 'wind', 'perc': 10.7}]},
#   {'from': '2024-05-02T12:30Z',
#    'to': '2024-05-02T13:00Z',
#    'intensity': {'forecast': 59, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 4.7},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 44.1},
#     {'fuel': 'gas', 'perc': 12.2},
#     {'fuel': 'nuclear', 'perc': 3.4},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 24.5},
#     {'fuel': 'wind', 'perc': 11}]},
#   {'from': '2024-05-02T13:00Z',
#    'to': '2024-05-02T13:30Z',
#    'intensity': {'forecast': 64, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.1},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 41.6},
#     {'fuel': 'gas', 'perc': 13.5},
#     {'fuel': 'nuclear', 'perc': 4.3},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 22.8},
#     {'fuel': 'wind', 'perc': 12.5}]},
#   {'from': '2024-05-02T13:30Z',
#    'to': '2024-05-02T14:00Z',
#    'intensity': {'forecast': 66, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 39},
#     {'fuel': 'gas', 'perc': 13.4},
#     {'fuel': 'nuclear', 'perc': 5.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 20.3},
#     {'fuel': 'wind', 'perc': 15.1}]},
#   {'from': '2024-05-02T14:00Z',
#    'to': '2024-05-02T14:30Z',
#    'intensity': {'forecast': 71, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 8.2},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 39.3},
#     {'fuel': 'gas', 'perc': 14.3},
#     {'fuel': 'nuclear', 'perc': 4.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 18},
#     {'fuel': 'wind', 'perc': 15.4}]},
#   {'from': '2024-05-02T14:30Z',
#    'to': '2024-05-02T15:00Z',
#    'intensity': {'forecast': 72, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 8.8},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 38},
#     {'fuel': 'gas', 'perc': 14.4},
#     {'fuel': 'nuclear', 'perc': 4.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 17.1},
#     {'fuel': 'wind', 'perc': 16.7}]},
#   {'from': '2024-05-02T15:00Z',
#    'to': '2024-05-02T15:30Z',
#    'intensity': {'forecast': 75, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 8.2},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 40.8},
#     {'fuel': 'gas', 'perc': 15.4},
#     {'fuel': 'nuclear', 'perc': 4.4},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 15.9},
#     {'fuel': 'wind', 'perc': 15}]},
#   {'from': '2024-05-02T15:30Z',
#    'to': '2024-05-02T16:00Z',
#    'intensity': {'forecast': 88, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7},
#     {'fuel': 'coal', 'perc': 0},
#     {'fuel': 'imports', 'perc': 41},
#     {'fuel': 'gas', 'perc': 19},
#     {'fuel': 'nuclear', 'perc': 4.5},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 14},
#     {'fuel': 'wind', 'perc': 14.2}]},
#   {'from': '2024-05-02T16:00Z',
#    'to': '2024-05-02T16:30Z',
#    'intensity': {'forecast': 104, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7.5},
#     {'fuel': 'coal', 'perc': 0.2},
#     {'fuel': 'imports', 'perc': 39.1},
#     {'fuel': 'gas', 'perc': 22.5},
#     {'fuel': 'nuclear', 'perc': 4.5},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.4},
#     {'fuel': 'solar', 'perc': 11.6},
#     {'fuel': 'wind', 'perc': 14.3}]},
#   {'from': '2024-05-02T16:30Z',
#    'to': '2024-05-02T17:00Z',
#    'intensity': {'forecast': 111, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7},
#     {'fuel': 'coal', 'perc': 1},
#     {'fuel': 'imports', 'perc': 39.9},
#     {'fuel': 'gas', 'perc': 22.5},
#     {'fuel': 'nuclear', 'perc': 6.4},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.6},
#     {'fuel': 'solar', 'perc': 8.7},
#     {'fuel': 'wind', 'perc': 14}]},
#   {'from': '2024-05-02T17:00Z',
#    'to': '2024-05-02T17:30Z',
#    'intensity': {'forecast': 122, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 9.3},
#     {'fuel': 'coal', 'perc': 2.1},
#     {'fuel': 'imports', 'perc': 33.3},
#     {'fuel': 'gas', 'perc': 22.5},
#     {'fuel': 'nuclear', 'perc': 6.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.8},
#     {'fuel': 'solar', 'perc': 6.5},
#     {'fuel': 'wind', 'perc': 18.5}]},
#   {'from': '2024-05-02T17:30Z',
#    'to': '2024-05-02T18:00Z',
#    'intensity': {'forecast': 133, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 8},
#     {'fuel': 'coal', 'perc': 2.4},
#     {'fuel': 'imports', 'perc': 38.9},
#     {'fuel': 'gas', 'perc': 24.4},
#     {'fuel': 'nuclear', 'perc': 5.7},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.8},
#     {'fuel': 'solar', 'perc': 4.2},
#     {'fuel': 'wind', 'perc': 15.6}]},
#   {'from': '2024-05-02T18:00Z',
#    'to': '2024-05-02T18:30Z',
#    'intensity': {'forecast': 140, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 7.6},
#     {'fuel': 'coal', 'perc': 2.6},
#     {'fuel': 'imports', 'perc': 40.8},
#     {'fuel': 'gas', 'perc': 26.1},
#     {'fuel': 'nuclear', 'perc': 5.1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.8},
#     {'fuel': 'solar', 'perc': 2.5},
#     {'fuel': 'wind', 'perc': 14.5}]},
#   {'from': '2024-05-02T18:30Z',
#    'to': '2024-05-02T19:00Z',
#    'intensity': {'forecast': 137, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6.8},
#     {'fuel': 'coal', 'perc': 2.5},
#     {'fuel': 'imports', 'perc': 44.2},
#     {'fuel': 'gas', 'perc': 25.3},
#     {'fuel': 'nuclear', 'perc': 3.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.7},
#     {'fuel': 'solar', 'perc': 1.2},
#     {'fuel': 'wind', 'perc': 15.5}]},
#   {'from': '2024-05-02T19:00Z',
#    'to': '2024-05-02T19:30Z',
#    'intensity': {'forecast': 145, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.2},
#     {'fuel': 'coal', 'perc': 2.3},
#     {'fuel': 'imports', 'perc': 47.3},
#     {'fuel': 'gas', 'perc': 28.4},
#     {'fuel': 'nuclear', 'perc': 3.2},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.6},
#     {'fuel': 'solar', 'perc': 0.3},
#     {'fuel': 'wind', 'perc': 12.6}]},
#   {'from': '2024-05-02T19:30Z',
#    'to': '2024-05-02T20:00Z',
#    'intensity': {'forecast': 128, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5},
#     {'fuel': 'coal', 'perc': 1.4},
#     {'fuel': 'imports', 'perc': 52.3},
#     {'fuel': 'gas', 'perc': 25.9},
#     {'fuel': 'nuclear', 'perc': 2.7},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0.3},
#     {'fuel': 'wind', 'perc': 12.1}]},
#   {'from': '2024-05-02T20:00Z',
#    'to': '2024-05-02T20:30Z',
#    'intensity': {'forecast': 120, 'index': 'moderate'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.5},
#     {'fuel': 'coal', 'perc': 1.1},
#     {'fuel': 'imports', 'perc': 54},
#     {'fuel': 'gas', 'perc': 24.6},
#     {'fuel': 'nuclear', 'perc': 2.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0.3},
#     {'fuel': 'wind', 'perc': 11.5}]},
#   {'from': '2024-05-02T20:30Z',
#    'to': '2024-05-02T21:00Z',
#    'intensity': {'forecast': 109, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 6.4},
#     {'fuel': 'coal', 'perc': 1.4},
#     {'fuel': 'imports', 'perc': 57.5},
#     {'fuel': 'gas', 'perc': 20.6},
#     {'fuel': 'nuclear', 'perc': 2.9},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 10.9}]},
#   {'from': '2024-05-02T21:00Z',
#    'to': '2024-05-02T21:30Z',
#    'intensity': {'forecast': 106, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 9.6},
#     {'fuel': 'coal', 'perc': 1.1},
#     {'fuel': 'imports', 'perc': 50.9},
#     {'fuel': 'gas', 'perc': 20.5},
#     {'fuel': 'nuclear', 'perc': 2.8},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0.3},
#     {'fuel': 'wind', 'perc': 14.5}]},
#   {'from': '2024-05-02T21:30Z',
#    'to': '2024-05-02T22:00Z',
#    'intensity': {'forecast': 92, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 2.1},
#     {'fuel': 'coal', 'perc': 0.6},
#     {'fuel': 'imports', 'perc': 64.9},
#     {'fuel': 'gas', 'perc': 18.8},
#     {'fuel': 'nuclear', 'perc': 1},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.3},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 12.2}]},
#   {'from': '2024-05-02T22:00Z',
#    'to': '2024-05-02T22:30Z',
#    'intensity': {'forecast': 108, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.3},
#     {'fuel': 'coal', 'perc': 1.6},
#     {'fuel': 'imports', 'perc': 57.2},
#     {'fuel': 'gas', 'perc': 21.1},
#     {'fuel': 'nuclear', 'perc': 2.6},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.2},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 12.1}]},
#   {'from': '2024-05-02T22:30Z',
#    'to': '2024-05-02T23:00Z',
#    'intensity': {'forecast': 108, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 5.5},
#     {'fuel': 'coal', 'perc': 1.2},
#     {'fuel': 'imports', 'perc': 58.9},
#     {'fuel': 'gas', 'perc': 21.8},
#     {'fuel': 'nuclear', 'perc': 1.5},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 11}]},
#   {'from': '2024-05-02T23:00Z',
#    'to': '2024-05-02T23:30Z',
#    'intensity': {'forecast': 99, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 2.5},
#     {'fuel': 'coal', 'perc': 0.9},
#     {'fuel': 'imports', 'perc': 63.7},
#     {'fuel': 'gas', 'perc': 20.2},
#     {'fuel': 'nuclear', 'perc': 1.5},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0.1},
#     {'fuel': 'wind', 'perc': 10.9}]},
#   {'from': '2024-05-02T23:30Z',
#    'to': '2024-05-03T00:00Z',
#    'intensity': {'forecast': 105, 'index': 'low'},
#    'generationmix': [{'fuel': 'biomass', 'perc': 1.6},
#     {'fuel': 'coal', 'perc': 0.8},
#     {'fuel': 'imports', 'perc': 63.6},
#     {'fuel': 'gas', 'perc': 22.1},
#     {'fuel': 'nuclear', 'perc': 1.4},
#     {'fuel': 'other', 'perc': 0},
#     {'fuel': 'hydro', 'perc': 0.1},
#     {'fuel': 'solar', 'perc': 0},
#     {'fuel': 'wind', 'perc': 10.4}]}]}

# %%
#Aplicamos pd.json_normalize para asignarle la estructura correspondiente al archivo
# Ver mas informacion de la pagina oficial de Pandas: https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html

regional_data_normalized = pd.json_normalize(regional_json_data['data'],
                                 record_path='generationmix',
                                 meta=['from', 'to', ['intensity', 'forecast'], ['intensity', 'index']],
                                 sep= '_')


#Obtenemos por separado la siguiente informacion del archivo .json y creamos la columnas correspondientes del DataFrame. En estos casos
#no es necesario aplicar json_normalize
regional_data_normalized['regionid'] = regional_json_data['regionid']
regional_data_normalized['dnoregion'] = regional_json_data['dnoregion']
regional_data_normalized['shortname'] = regional_json_data['shortname']
regional_data_normalized['postcode'] = regional_json_data['postcode']

regional_data_normalized.head()
# Out:
#       fuel  perc               from                 to intensity_forecast  \
# 0  biomass   7.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 1     coal   1.5  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 2  imports  52.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 3      gas  31.9  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 4  nuclear   0.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
#
#   intensity_index  regionid  dnoregion      shortname postcode
# 0        moderate        12  SSE South  South England     RG10
# 1        moderate        12  SSE South  South England     RG10
# 2        moderate        12  SSE South  South England     RG10
# 3        moderate        12  SSE South  South England     RG10
# 4        moderate        12  SSE South  South England     RG10

# %%
#Informacion del tipo de dato de cada una de las columnas
regional_data_normalized.info()


# Crear una tabla o archivo Delta Lake vacío
DeltaTable.create(table_uri="datalakehouse/1_bronze/carbon_intensity_api/regional",
     # Columnas y tipos de datos
                  schema = pa.schema([
                      pa.field("fuel", pa.string()),
                      pa.field("perc", pa.float64()),
                      pa.field("from", pa.string()),
                      pa.field("to", pa.string()),
                      pa.field("intensity_forecast", pa.string()),
                      pa.field("intensity_index", pa.string()),
                      pa.field("regionid", pa.int64()),
                      pa.field("dnoregion", pa.string()),
                      pa.field("shortname", pa.string()),
                      pa.field("postcode", pa.string())
                      ]),
                  mode="ignore", #Si se selecciona 'ignore', no realizará ninguna acción si la tabla ya existe.
                  description="Tabla de datos crudos de tipos de combustibles",
                  # Configuraciones de la tabla
                  # Etiquedas o tags adicionales, para sumar metadata.
                  custom_metadata={
                      "source": "NESO" #National Energy System Operator
                  },
                  configuration={
                      "delta.deletedFileRetentionDuration": "interval 7 day",
                      "delta.logRetentionDuration": "interval 7 day",
                      "delta.enableChangeDataFeed": "true",
    }                  )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 873 entries, 0 to 872
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fuel                873 non-null    object
#  1   perc                873 non-null    float64
#  2   from                873 non-null    object
#  3   to                  873 non-null    object
#  4   intensity_forecast  873 non-null    object
#  5   intensity_index     873 non-null    object
#  6   regionid            873 non-null    int64
#  7   dnoregion           873 non-null    object
#  8   shortname           873 non-null    object
#  9   postcode            873 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 68.3+ KB
# DeltaTable()

# %%
# @title
from IPython.display import HTML

html_code = """
<div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
<strong>Utilizando la funcion "save_new_data_as_delta":</strong>
Guarda solo nuevos datos en formato Delta Lake usando la operación MERGE, comparando los datos ya cargados con los datos que se desean almacenar asegurando que no se guarden registros duplicados.<br>
<br>
<strong><i>Es importante destacar que merge, en la funcion "save_new_data_as_delta", opera sobre DeltaTable por lo tanto no modifica el DataFrame original</i></strong><br>
<br></div>
"""

display(HTML(html_code))
# Out:
# <div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
# <strong>Utilizando la funcion "save_new_data_as_delta":</strong>
# Guarda solo nuevos datos en formato Delta Lake usando la operación MERGE, comparando los datos ya cargados con los datos que se desean almacenar asegurando que no se guarden registros duplicados.<br>
# <br>
# <strong><i>Es importante destacar que merge, en la funcion "save_new_data_as_delta", opera sobre DeltaTable por lo tanto no modifica el DataFrame original</i></strong><br>
# <br></div>

# %%
save_new_data_as_delta(
    regional_data_normalized,
    "datalakehouse/1_bronze/carbon_intensity_api/regional",
    """target.from = source.from
    AND target.intensity_forecast = source.intensity_forecast
    AND target.intensity_index = source.intensity_index""",
    partition_cols=None
)


# #Copiamos la ruta del archivo .parquet, que queremos consultar, con el boton derecho del mouse y le aplicamos "pd.read_parquet()"
# info_parquet =pd.read_parquet("/content/datalakehouse/1_bronze/carbon_intensity_api/regional/part-00001-f26adcf4-0afa-476f-bebb-6a9ebc8d5138-c000.snappy.parquet", engine="auto")

# #Luego obtenemos la informacion relacionada al mismo
# info_parquet.info()

# %%
#Accedemos a la tabla almacenada
regional_table = DeltaTable("datalakehouse/1_bronze/carbon_intensity_api/regional")

#La convertimos a DataFrame
regional_table_normalized = regional_table.to_pandas()


#Accedemos a la tabla para conseguir informacion relacionada a cada campo en formato .json
json_schema = regional_table.schema().to_json() # resultado: str
json_schema = json.loads(json_schema) # resultado: Dict
json_schema["fields"]

#Aplicamos pd.json_normalize para asignarle la estructura correspondiente al archivo
pd.json_normalize(json_schema, record_path="fields")
# Out:
#                  name    type  nullable
# 0                fuel  string      True
# 1                perc  double      True
# 2                from  string      True
# 3                  to  string      True
# 4  intensity_forecast  string      True
# 5     intensity_index  string      True
# 6            regionid    long      True
# 7           dnoregion  string      True
# 8           shortname  string      True
# 9            postcode  string      True

# %%
regional_table_normalized
# Out:
#         fuel  perc               from                 to intensity_forecast  \
# 0    biomass   7.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 1       coal   1.5  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 2    imports  52.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 3        gas  31.9  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 4    nuclear   0.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# ..       ...   ...                ...                ...                ...
# 868  nuclear   1.5  2024-05-02T23:00Z  2024-05-02T23:30Z                 99
# 869    other   0.0  2024-05-02T23:00Z  2024-05-02T23:30Z                 99
# 870    hydro   0.1  2024-05-02T23:00Z  2024-05-02T23:30Z                 99
# 871    solar   0.1  2024-05-02T23:00Z  2024-05-02T23:30Z                 99
# 872     wind  10.9  2024-05-02T23:00Z  2024-05-02T23:30Z                 99
#
#     intensity_index  regionid  dnoregion      shortname postcode
# 0          moderate        12  SSE South  South England     RG10
# 1          moderate        12  SSE South  South England     RG10
# 2          moderate        12  SSE South  South England     RG10
# 3          moderate        12  SSE South  South England     RG10
# 4          moderate        12  SSE South  South England     RG10
# ..              ...       ...        ...            ...      ...
# 868             low        12  SSE South  South England     RG10
# 869             low        12  SSE South  South England     RG10
# 870             low        12  SSE South  South England     RG10
# 871             low        12  SSE South  South England     RG10
# 872             low        12  SSE South  South England     RG10
#
# [873 rows x 10 columns]

# %%
# @title
from IPython.display import HTML

html_code = """
<div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
<strong>Extraccion incremental (o delta):</strong> consiste en recolectar actualizaciones de la fuente de datos, ya sea por la
inserción de nuevos registros o la modificación de los existentes. En lugar de
extraer todos los datos, se realizan consultas que seleccionan solo los datos
nuevos o modificados desde la última extracción.
El rastreo de cambios en esta técnica es posible si la fuente de datos cuenta
con algún campo de identificación o con alguna marca de tiempo, como por ejemplo la fecha y la hora.</div>
"""

display(HTML(html_code))
# Out:
# <div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
# <strong>Extraccion incremental (o delta):</strong> consiste en recolectar actualizaciones de la fuente de datos, ya sea por la
# inserción de nuevos registros o la modificación de los existentes. En lugar de
# extraer todos los datos, se realizan consultas que seleccionan solo los datos
# nuevos o modificados desde la última extracción.
# El rastreo de cambios en esta técnica es posible si la fuente de datos cuenta
# con algún campo de identificación o con alguna marca de tiempo, como por ejemplo la fecha y la hora.</div>

# %%
##############################################################
#              EXTRACCION INCREMENTAL STATELESS              #
##############################################################



#Obtener mediciones de la última hora

endpoint_time = "intensity"

start_date = datetime.utcnow() - timedelta(hours=1)

# Formatear objetos fecha a string, y definir inicio y fin
end_date = start_date.strftime("%Y-%m-%dT%H:59:59Z")
start_date = start_date.strftime("%Y-%m-%dT%H:00:00Z")

endpoint_time = f"{endpoint_time}/{start_date}/{end_date}"

time = get_data(base_url, endpoint_time, "data")
time_df = build_table(time)

# Renombrar las columnas
time_df = time_df.rename(columns={'from': 'fecha_desde', 'to': 'fecha_hasta',
                                                    'intensity.forecast': 'intensity_forecast',
                                                    'intensity.actual': 'intensity_actual'})


print(f"fecha desde: {start_date}")
print(f"fecha hasta: {end_date}")


time_df
# Out:
# C:\Users\Willy\AppData\Local\Temp\ipykernel_13792\2822567006.py:11: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start_date = datetime.utcnow() - timedelta(hours=1)
# fecha desde: 2025-05-11T19:00:00Z
# fecha hasta: 2025-05-11T19:59:59Z
#          fecha_desde        fecha_hasta  intensity_forecast  intensity_actual  \
# 0  2025-05-11T18:30Z  2025-05-11T19:00Z                 119               111
# 1  2025-05-11T19:00Z  2025-05-11T19:30Z                 116               113
#
#   intensity.index
# 0        moderate
# 1        moderate

# %%
# Antes de hacer el procesamiento
# Vamos a inspeccionar el DataFrame
# La siguiente libreria nos da info como la cantidad de nulos, duplicados, etc.
profile = ProfileReport(regional_table_normalized)
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 63.04it/s][A
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-05-11 20:30:58.190550&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
#Creamos nuestro directorio haciendo referencia a la capa Bronze sobre la cual iniciamos nuestra carga
bronze_dir = "datalakehouse/1_bronze/carbon_intensity_api"


#Separamos la fecha y la hora para almacenarlas en carpetas diferentes. De esta forma tendremos un detalle pormenorizado de las
#modificaciones que se produzcan cada hora.

time_df["fecha_desde"] = pd.to_datetime(time_df.fecha_desde)
time_df["fecha"] = time_df.fecha_desde.dt.date
# time_df["hora"] = time_df.fecha_desde.dt.hour (dt.hour toma la hora en formato int y no coincide con el formato str de strftime("%H"))
time_df["hora"] = time_df.fecha_desde.dt.strftime("%H")


time_raw_dir = f"{bronze_dir}/intensity/time"


#A continuación se ve la aplicación de la operación MERGE, donde se insertan los datos.

#Si al comparar actual_data y new_data hay registros con el mismo predicado,
#podemos omitir las coincidencias y solo insertar los registros que no coincidan.

#Si no hay registros con la misma fecha_desde / intensity_forecast / intensity_actual
#se insertará el registro de new_data.

save_new_data_as_delta(
    time_df,
    time_raw_dir,
    """target.fecha_desde = source.fecha_desde
    AND target.intensity_forecast = source.intensity_forecast
    AND target.intensity_actual = source.intensity_actual""",
    partition_cols=["fecha", "hora"]
    )

# %%
# @title
from IPython.display import HTML

html_code = """
<div style="background-color: lightpink; padding: 15px; border-radius: 5px; color: darkred;">
<strong><i>Módulo Nº2 - Unidad Nº 1</i></strong><br>
<br>
Procesamiento de datos</div>
"""

display(HTML(html_code))
# Out:
# <div style="background-color: lightpink; padding: 15px; border-radius: 5px; color: darkred;">
# <strong><i>Módulo Nº2 - Unidad Nº 1</i></strong><br>
# <br>
# Procesamiento de datos</div>

# %%
# @title
from IPython.display import HTML

html_code = """


<div style="background-color: white; padding: 15px; border-radius: 5px; color: black;">
<strong>Los Data Lakes se dividen típicamente en zonas o capas para organizar y gestionar los datos de manera eficiente. Estas zonas representan diferentes niveles de procesamiento y
gobernanza sobre los datos almacenados.</strong></div><br>
<br>

<div style="background-color: peachpuff; padding: 15px; border-radius: 5px; color: black;">
<strong><i>1. Bronze:</i></strong> también conocida como “Landing” o “raw data”, es la primera
capa en un Data Lake. Aquí es donde los datos aterrizan desde diversas
fuentes, por medio de pipelines, sin realizar transformaciones significativas.
Los datos se almacenan en su forma bruta, preservando su integridad
original. En esta capa, se pueden incluir datos estructurados, semiestructurados y no estructurados, por eso los formatos a usar aquí pueden
variar.</div><br>
<br>

<div style="background-color: #f0f0f0; padding: 15px; border-radius: 5px; color: black;">
<strong>2. Silver:</strong>
 es donde los datos crudos se transforman y preparan para un uso
más amplio. Aquí se aplican procesos de limpieza, normalización, de
duplicación, validación y otras transformaciones para mejorar la calidad
y la estructura de los datos. Esta capa tiene como objetivo ofrecer datos
9
de calidad, más estructurados y listos para los equipos de análisis y ciencia
de datos.</div><br>
<br>

<div style="background-color: gold; padding: 15px; border-radius: 5px; color: black;">
<strong>3. Gold:</strong>
 es la capa final en un Data Lake, donde se ofrecen datos
enriquecidos y de valor para la organización. Aquí se aplican reglas de
negocio y se realizan agregaciones, cálculos, agrupaciones, transformaciones más
avanzadas y se optimizan los datos para casos de uso específicos.</div><br>
<br>
"""

display(HTML(html_code))
# Out:
# <div style="background-color: white; padding: 15px; border-radius: 5px; color: black;">
# <strong>Los Data Lakes se dividen típicamente en zonas o capas para organizar y gestionar los datos de manera eficiente. Estas zonas representan diferentes niveles de procesamiento y
# gobernanza sobre los datos almacenados.</strong></div><br>
# <br>
#
# <div style="background-color: peachpuff; padding: 15px; border-radius: 5px; color: black;">
# <strong><i>1. Bronze:</i></strong> también conocida como “Landing” o “raw data”, es la primera
# capa en un Data Lake. Aquí es donde los datos aterrizan desde diversas
# fuentes, por medio de pipelines, sin realizar transformaciones significativas.
# Los datos se almacenan en su forma bruta, preservando su integridad
# original. En esta capa, se pueden incluir datos estructurados, semiestructurados y no estructurados, por eso los formatos a usar aquí pueden
# variar.</div><br>
# <br>
#
# <div style="background-color: #f0f0f0; padding: 15px; border-radius: 5px; color: black;">
# <strong>2. Silver:</strong>
#  es donde los datos crudos se transforman y preparan para un uso
# más amplio. Aquí se aplican procesos de limpieza, normalización, de
# duplicación, validación y otras transformaciones para mejorar la calidad
# y la estructura de los datos. Esta capa tiene como objetivo ofrecer datos
# 9
# de calidad, más estructurados y listos para los equipos de análisis y ciencia
# de datos.</div><br>
# <br>
#
# <div style="background-color: gold; padding: 15px; border-radius: 5px; color: black;">
# <strong>3. Gold:</strong>
#  es la capa final en un Data Lake, donde se ofrecen datos
# enriquecidos y de valor para la organización. Aquí se aplican reglas de
# negocio y se realizan agregaciones, cálculos, agrupaciones, transformaciones más
# avanzadas y se optimizan los datos para casos de uso específicos.</div><br>
# <br>

# %%
#Trabajamos con la extraccion full


#Excluimos del DataFrame las filas cuyo valor sea igual a cero en la columna "percentage", ya que no aportan informacion a nuestro analisis
regional_table_normalized = regional_table_normalized[regional_table_normalized['perc'] != 0]

regional_table_normalized.head()
# Out:
#       fuel  perc               from                 to intensity_forecast  \
# 0  biomass   7.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 1     coal   1.5  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 2  imports  52.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 3      gas  31.9  2024-04-30T23:30Z  2024-05-01T00:00Z                156
# 4  nuclear   0.7  2024-04-30T23:30Z  2024-05-01T00:00Z                156
#
#   intensity_index  regionid  dnoregion      shortname postcode
# 0        moderate        12  SSE South  South England     RG10
# 1        moderate        12  SSE South  South England     RG10
# 2        moderate        12  SSE South  South England     RG10
# 3        moderate        12  SSE South  South England     RG10
# 4        moderate        12  SSE South  South England     RG10

# %%
#Realizamos una copia del DataFrame "regional_table_normalized"
regional_table_cast = regional_table_normalized.copy()

#Convertimos a formato datetime las columnas 'from' y 'to'
regional_table_cast['from'] = pd.to_datetime(regional_table_cast['from'], format='mixed')
regional_table_cast['to'] = pd.to_datetime(regional_table_cast['to'], format='mixed')

regional_table_cast.head()
# Out:
#       fuel  perc                      from                        to  \
# 0  biomass   7.7 2024-04-30 23:30:00+00:00 2024-05-01 00:00:00+00:00
# 1     coal   1.5 2024-04-30 23:30:00+00:00 2024-05-01 00:00:00+00:00
# 2  imports  52.7 2024-04-30 23:30:00+00:00 2024-05-01 00:00:00+00:00
# 3      gas  31.9 2024-04-30 23:30:00+00:00 2024-05-01 00:00:00+00:00
# 4  nuclear   0.7 2024-04-30 23:30:00+00:00 2024-05-01 00:00:00+00:00
#
#   intensity_forecast intensity_index  regionid  dnoregion      shortname  \
# 0                156        moderate        12  SSE South  South England
# 1                156        moderate        12  SSE South  South England
# 2                156        moderate        12  SSE South  South England
# 3                156        moderate        12  SSE South  South England
# 4                156        moderate        12  SSE South  South England
#
#   postcode
# 0     RG10
# 1     RG10
# 2     RG10
# 3     RG10
# 4     RG10

# %%
#Casteo
#La opcion "category" aplica para string y enteros
conversion_mapping = {
    "regionid" : "category",
    "dnoregion" : "category",
    "shortname" : "category",
    "postcode" : "category",
    "from" : "datetime64[ns]",
    "to" : "datetime64[ns]",
    "intensity_forecast" : "int16",
    "intensity_index" : "category",
    "fuel" : "category",
    "perc" : "float64"
}

# Convierte 'from' y 'to' a columnas timezone-naive
regional_table_cast['from'] = regional_table_cast['from'].dt.tz_localize(None)
regional_table_cast['to'] = regional_table_cast['to'].dt.tz_localize(None)

regional_table_cast = regional_table_cast.astype(conversion_mapping)

regional_table_cast.info()
#A partir de aplicar el casteo obtenemos una reduccion del 44% en la utilizacion de memoria
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 675 entries, 0 to 872
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fuel                675 non-null    category
#  1   perc                675 non-null    float64
#  2   from                675 non-null    datetime64[ns]
#  3   to                  675 non-null    datetime64[ns]
#  4   intensity_forecast  675 non-null    int16
#  5   intensity_index     675 non-null    category
#  6   regionid            675 non-null    category
#  7   dnoregion           675 non-null    category
#  8   shortname           675 non-null    category
#  9   postcode            675 non-null    category
# dtypes: category(6), datetime64[ns](2), float64(1), int16(1)
# memory usage: 27.3 KB

# %%
#Aplicamos formato a las columnas de fecha para obtener el dia-mes-año
regional_table_cast['from'] = regional_table_cast['from'].dt.strftime("%d-%m-%Y")
regional_table_cast['to'] = regional_table_cast['to'].dt.strftime("%d-%m-%Y")


#Renombramos las columnas
regional_table_cast = regional_table_cast.rename(columns={
    'shortname': 'nombre_corto',
    'postcode': 'codigo_postal',
    'from': 'fecha_desde',
    'to': 'fecha_hasta',
    'intensity_forecast': 'pronostico_intensidad',
    'intensity_index': 'indice_intensidad',
    'fuel': 'combustible',
    'perc': 'porcentaje'
    })

regional_table_cast.head()
# Out:
#   combustible  porcentaje fecha_desde fecha_hasta  pronostico_intensidad  \
# 0     biomass         7.7  30-04-2024  01-05-2024                    156
# 1        coal         1.5  30-04-2024  01-05-2024                    156
# 2     imports        52.7  30-04-2024  01-05-2024                    156
# 3         gas        31.9  30-04-2024  01-05-2024                    156
# 4     nuclear         0.7  30-04-2024  01-05-2024                    156
#
#   indice_intensidad regionid  dnoregion   nombre_corto codigo_postal
# 0          moderate       12  SSE South  South England          RG10
# 1          moderate       12  SSE South  South England          RG10
# 2          moderate       12  SSE South  South England          RG10
# 3          moderate       12  SSE South  South England          RG10
# 4          moderate       12  SSE South  South England          RG10

# %%
# Guardar en Silver
save_new_data_as_delta(
    regional_table_cast,
    "datalakehouse/2_silver/carbon_intensity_api/regional",
    """target.fecha_desde = source.fecha_desde
    AND target.porcentaje = source.porcentaje""",
    partition_cols=None
)

# %%
#Accedemos a la tabla almacenada en Silver
regional_dt_silver = DeltaTable("datalakehouse/2_silver/carbon_intensity_api/regional")

#La convertimos a DataFrame
regional_normalized_silver = regional_dt_silver.to_pandas()


#Ordenamos las compañias que segun su cantidad (de mayor a menor)
# Conservamos el original "regional_table_cast" con todas las columnas
original_table_cast = regional_normalized_silver.copy()

# Subset para grouping y aggregation
table_cast_subset = original_table_cast[["combustible", "porcentaje", "fecha_desde"]]

regional_gold_cleaned = table_cast_subset.groupby(['combustible', 'fecha_desde'], observed=False).sum().sort_values(by = 'fecha_desde', ascending=False)

regional_gold_cleaned.reset_index(inplace = True)

regional_gold_cleaned
# Out:
#    combustible fecha_desde  porcentaje
# 0        hydro  30-04-2024         0.1
# 1         coal  30-04-2024         1.5
# 2      nuclear  30-04-2024         0.7
# 3      imports  30-04-2024        52.7
# 4          gas  30-04-2024        31.9
# 5         wind  30-04-2024         5.3
# 6      biomass  30-04-2024         7.7
# 7         coal  02-05-2024        42.2
# 8         wind  02-05-2024       622.1
# 9        hydro  02-05-2024        16.0
# 10     biomass  02-05-2024       276.7
# 11     imports  02-05-2024      2319.9
# 12         gas  02-05-2024      1032.9
# 13       solar  02-05-2024       369.9
# 14     nuclear  02-05-2024       119.7
# 15         gas  01-05-2024      1902.9
# 16       solar  01-05-2024       384.2
# 17        wind  01-05-2024       207.7
# 18        coal  01-05-2024        21.4
# 19     nuclear  01-05-2024        27.2
# 20     imports  01-05-2024      2079.7
# 21       hydro  01-05-2024        23.6
# 22     biomass  01-05-2024       152.9

# %%
# Guardar en Gold
save_new_data_as_delta(
    regional_gold_cleaned,
    "datalakehouse/3_gold/carbon_intensity_api/regional",
    """target.fecha_desde = source.fecha_desde
    AND target.porcentaje = source.porcentaje""",
    partition_cols=None
)

# %%
#Trabajamos con la extraccion incremental


#Leemos la ultima particion de la extraccion incremental
time_df_bronze = read_most_recent_partition(time_raw_dir)


#Renombramos las columnas en forma dinamica. Reemplazara el "." por el "_" en aquellas columnas que lo tengan
time_df_bronze = time_df_bronze.rename(
    columns=lambda col: col.replace(".", "_")
)

time_df_bronze
# Out:
# C:\Users\Willy\AppData\Local\Temp\ipykernel_13792\1718803077.py:92: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   requested_date = datetime.utcnow() - timedelta(hours=1)
#                 fecha_desde        fecha_hasta  intensity_forecast  \
# 0 2025-05-11 19:00:00+00:00  2025-05-11T19:30Z                 116
#
#    intensity_actual intensity_index       fecha hora
# 0               113        moderate  2025-05-11   19

# %%
#Completamos el DataFrame con mas datos y nuevas columnas
df1 = pd.DataFrame({'fuel': ['gas', 'coal', 'biomass', 'nuclear', 'hydro', 'imports', 'other', 'wind', 'solar'],
                    'perc': [43.6, 0.7, 4.2, 17.6, 2.2, 6.5, 0.3, 6.8, 18.1]})

df1['regionid'] = 3
df1['dnoregion'] = "Electricity North West"

# Unión por columnas
time_df_silver = pd.concat([df1, time_df_bronze], axis=1)

#Eliminamos la columna 'fecha_hasta'
time_df_silver = time_df_silver.drop(columns=['fecha_hasta'])

time_df_silver
# Out:
#       fuel  perc  regionid               dnoregion               fecha_desde  \
# 0      gas  43.6         3  Electricity North West 2025-05-11 19:00:00+00:00
# 1     coal   0.7         3  Electricity North West                       NaT
# 2  biomass   4.2         3  Electricity North West                       NaT
# 3  nuclear  17.6         3  Electricity North West                       NaT
# 4    hydro   2.2         3  Electricity North West                       NaT
# 5  imports   6.5         3  Electricity North West                       NaT
# 6    other   0.3         3  Electricity North West                       NaT
# 7     wind   6.8         3  Electricity North West                       NaT
# 8    solar  18.1         3  Electricity North West                       NaT
#
#    intensity_forecast  intensity_actual intensity_index       fecha hora
# 0               116.0             113.0        moderate  2025-05-11   19
# 1                 NaN               NaN             NaN         NaN  NaN
# 2                 NaN               NaN             NaN         NaN  NaN
# 3                 NaN               NaN             NaN         NaN  NaN
# 4                 NaN               NaN             NaN         NaN  NaN
# 5                 NaN               NaN             NaN         NaN  NaN
# 6                 NaN               NaN             NaN         NaN  NaN
# 7                 NaN               NaN             NaN         NaN  NaN
# 8                 NaN               NaN             NaN         NaN  NaN

# %%
#Completamos los valores NaN con el correspondiente dato de la primera fila de cada columna
imputation_mapping = {
    #Obtenemos el valor de la primera fila de cada columna
    'fecha_desde': time_df_silver.loc[0, "fecha_desde"],
    'intensity_forecast': time_df_silver.loc[0, "intensity_forecast"],
    'intensity_actual': time_df_silver.loc[0, "intensity_actual"],
    'intensity_index': time_df_silver.loc[0, "intensity_index"],
    'fecha': time_df_silver.loc[0, "fecha"],
    'hora':	time_df_silver.loc[0, "hora"]
}

time_df_silver = time_df_silver.fillna(imputation_mapping)

time_df_silver
# Out:
#       fuel  perc  regionid               dnoregion               fecha_desde  \
# 0      gas  43.6         3  Electricity North West 2025-05-11 19:00:00+00:00
# 1     coal   0.7         3  Electricity North West 2025-05-11 19:00:00+00:00
# 2  biomass   4.2         3  Electricity North West 2025-05-11 19:00:00+00:00
# 3  nuclear  17.6         3  Electricity North West 2025-05-11 19:00:00+00:00
# 4    hydro   2.2         3  Electricity North West 2025-05-11 19:00:00+00:00
# 5  imports   6.5         3  Electricity North West 2025-05-11 19:00:00+00:00
# 6    other   0.3         3  Electricity North West 2025-05-11 19:00:00+00:00
# 7     wind   6.8         3  Electricity North West 2025-05-11 19:00:00+00:00
# 8    solar  18.1         3  Electricity North West 2025-05-11 19:00:00+00:00
#
#    intensity_forecast  intensity_actual intensity_index       fecha hora
# 0               116.0             113.0        moderate  2025-05-11   19
# 1               116.0             113.0        moderate  2025-05-11   19
# 2               116.0             113.0        moderate  2025-05-11   19
# 3               116.0             113.0        moderate  2025-05-11   19
# 4               116.0             113.0        moderate  2025-05-11   19
# 5               116.0             113.0        moderate  2025-05-11   19
# 6               116.0             113.0        moderate  2025-05-11   19
# 7               116.0             113.0        moderate  2025-05-11   19
# 8               116.0             113.0        moderate  2025-05-11   19

# %%
# Guardar en Silver

#A continuación se ve la aplicación de la operación MERGE, donde se insertan los datos.

#Si al comparar actual_data y new_data hay registros con el mismo predicado,
#podemos omitir las coincidencias y solo insertar los registros que no coincidan.

#Si no hay registros con la misma fecha_desde / intensity_forecast / intensity_actual
#se INSERTARA el registro de new_data.

measurements_silver_dir = 'datalakehouse/2_silver/carbon_intensity_api/intensity/time'
save_new_data_as_delta(
    time_df_silver,
    measurements_silver_dir,
    """target.fecha_desde = source.fecha_desde
    AND target.intensity_forecast = source.intensity_forecast
    AND target.intensity_actual = source.intensity_actual""",
    partition_cols=["fecha", "hora"]
)

# %%
#Accedemos a la tabla almacenada en Silver
time_dt_silver = DeltaTable("datalakehouse/2_silver/carbon_intensity_api/intensity/time")

#La convertimos a DataFrame
time_normalized_silver = time_dt_silver.to_pandas()


#Ingresamos formulas al procesamiento para obtener mas informacion

#Calculamos la diferencia entre 'intensity_actual' e 'intensity_forecast'
time_normalized_silver['diff'] =  time_normalized_silver['intensity_actual'] - time_normalized_silver['intensity_forecast']

#Establecemos una formula que determine si la diferencia entre 'intensity_actual' e 'intensity_forecast' subio, bajo o se mantuvo igual
time_normalized_silver['trend'] = time_normalized_silver.apply(lambda row: 'up' if row['intensity_actual'] - row['intensity_forecast'] > 0
                        else 'down' if row['intensity_actual'] - row['intensity_forecast'] < 0
                        else 'equal', axis=1)


time_normalized_silver
# Out:
#       fuel  perc  regionid               dnoregion               fecha_desde  \
# 0      gas  43.6         3  Electricity North West 2025-05-11 19:00:00+00:00
# 1     coal   0.7         3  Electricity North West 2025-05-11 19:00:00+00:00
# 2  biomass   4.2         3  Electricity North West 2025-05-11 19:00:00+00:00
# 3  nuclear  17.6         3  Electricity North West 2025-05-11 19:00:00+00:00
# 4    hydro   2.2         3  Electricity North West 2025-05-11 19:00:00+00:00
# 5  imports   6.5         3  Electricity North West 2025-05-11 19:00:00+00:00
# 6    other   0.3         3  Electricity North West 2025-05-11 19:00:00+00:00
# 7     wind   6.8         3  Electricity North West 2025-05-11 19:00:00+00:00
# 8    solar  18.1         3  Electricity North West 2025-05-11 19:00:00+00:00
#
#    intensity_forecast  intensity_actual intensity_index       fecha hora  \
# 0               116.0             113.0        moderate  2025-05-11   19
# 1               116.0             113.0        moderate  2025-05-11   19
# 2               116.0             113.0        moderate  2025-05-11   19
# 3               116.0             113.0        moderate  2025-05-11   19
# 4               116.0             113.0        moderate  2025-05-11   19
# 5               116.0             113.0        moderate  2025-05-11   19
# 6               116.0             113.0        moderate  2025-05-11   19
# 7               116.0             113.0        moderate  2025-05-11   19
# 8               116.0             113.0        moderate  2025-05-11   19
#
#    diff trend
# 0  -3.0  down
# 1  -3.0  down
# 2  -3.0  down
# 3  -3.0  down
# 4  -3.0  down
# 5  -3.0  down
# 6  -3.0  down
# 7  -3.0  down
# 8  -3.0  down

# %%
#Creamos un DataFrame que contenga el ID correspondiente a cada tipo de combustible
df_id = pd.DataFrame({'fuel': ['gas', 'coal', 'biomass', 'nuclear', 'hydro', 'imports', 'other', 'wind', 'solar'],
                    'id_num': [1, 2, 3, 4, 5, 6, 7, 8, 9]})


#Completamos el DataFrame "time_normalized_silver" con el ID de los combustibles utilizando left_join
time_df_silver = pd.merge(time_normalized_silver, df_id, on='fuel', how='left')


#Reordenamos las columnas para facilitar la lectura del DF y quitamos la que no utilizamos
time_df_silver = time_df_silver.reindex(columns=['id_num', 'fuel', 'perc', 'regionid', 'fecha_desde',
       'intensity_forecast', 'intensity_actual', 'diff', 'trend', 'intensity_index', 'fecha',
       'hora'])

time_df_silver
# Out:
#    id_num     fuel  perc  regionid               fecha_desde  \
# 0       1      gas  43.6         3 2025-05-11 19:00:00+00:00
# 1       2     coal   0.7         3 2025-05-11 19:00:00+00:00
# 2       3  biomass   4.2         3 2025-05-11 19:00:00+00:00
# 3       4  nuclear  17.6         3 2025-05-11 19:00:00+00:00
# 4       5    hydro   2.2         3 2025-05-11 19:00:00+00:00
# 5       6  imports   6.5         3 2025-05-11 19:00:00+00:00
# 6       7    other   0.3         3 2025-05-11 19:00:00+00:00
# 7       8     wind   6.8         3 2025-05-11 19:00:00+00:00
# 8       9    solar  18.1         3 2025-05-11 19:00:00+00:00
#
#    intensity_forecast  intensity_actual  diff trend intensity_index  \
# 0               116.0             113.0  -3.0  down        moderate
# 1               116.0             113.0  -3.0  down        moderate
# 2               116.0             113.0  -3.0  down        moderate
# 3               116.0             113.0  -3.0  down        moderate
# 4               116.0             113.0  -3.0  down        moderate
# 5               116.0             113.0  -3.0  down        moderate
# 6               116.0             113.0  -3.0  down        moderate
# 7               116.0             113.0  -3.0  down        moderate
# 8               116.0             113.0  -3.0  down        moderate
#
#         fecha hora
# 0  2025-05-11   19
# 1  2025-05-11   19
# 2  2025-05-11   19
# 3  2025-05-11   19
# 4  2025-05-11   19
# 5  2025-05-11   19
# 6  2025-05-11   19
# 7  2025-05-11   19
# 8  2025-05-11   19

# %%
# Casteo
type_mapping = {
    "id_num": "int16",
    "fuel": "category",
    "regionid": "category",
    "intensity_forecast": "int16",
    "intensity_actual": "int16",
    "diff": "int16",
    "trend": "category",
    "intensity_index": "category"
    }

time_df_silver = time_df_silver.astype(type_mapping)

#time_df_silver.info()

time_df_silver.head()
# Out:
#    id_num     fuel  perc regionid               fecha_desde  \
# 0       1      gas  43.6        3 2025-05-11 19:00:00+00:00
# 1       2     coal   0.7        3 2025-05-11 19:00:00+00:00
# 2       3  biomass   4.2        3 2025-05-11 19:00:00+00:00
# 3       4  nuclear  17.6        3 2025-05-11 19:00:00+00:00
# 4       5    hydro   2.2        3 2025-05-11 19:00:00+00:00
#
#    intensity_forecast  intensity_actual  diff trend intensity_index  \
# 0                 116               113    -3  down        moderate
# 1                 116               113    -3  down        moderate
# 2                 116               113    -3  down        moderate
# 3                 116               113    -3  down        moderate
# 4                 116               113    -3  down        moderate
#
#         fecha hora
# 0  2025-05-11   19
# 1  2025-05-11   19
# 2  2025-05-11   19
# 3  2025-05-11   19
# 4  2025-05-11   19

# %%
# Guardar en Gold

#A continuación se ve la aplicación de la operación MERGE, donde se insertan los datos.

#Si al comparar actual_data y new_data hay registros con el mismo predicado,
#podemos omitir las coincidencias y solo insertar los registros que no coincidan.

#Si no hay registros con la misma fecha_desde / intensity_forecast / intensity_actual
#se INSERTARA el registro de new_data.

measurements_gold_dir = 'datalakehouse/3_gold/carbon_intensity_api/intensity/time'
save_new_data_as_delta(
    time_df_silver,
    measurements_gold_dir,
    """target.fecha_desde = source.fecha_desde
    AND target.intensity_forecast = source.intensity_forecast
    AND target.intensity_actual = source.intensity_actual""",
    partition_cols=["fecha", "hora"]
)


#Accedemos a la tabla almacenada
gold_table_intensity = DeltaTable("datalakehouse/3_gold/carbon_intensity_api/intensity/time")

#La convertimos a DataFrame
gold_table_intensity = gold_table_intensity.to_pandas()

# %%
# @title
from IPython.display import HTML

html_code = """
<div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
<strong><i>Conclusión:</i></strong><br>
<br>
Delta Lake es una tecnología que permite almacenar datos de manera tabular y columnar, con la capacidad de realizar operaciones de lectura y escritura de datos de manera
 transaccional, lo que garantiza la integridad de los datos almacenados.
Si bien realizamos operacion de lectura y escritura, además de agregar restricciones, es posible también por ejemplo realizar operaciones de eliminación de datos, consultar
 versiones pasadas de los datos, etc.
Las tabla delta lake permiten agregar metadatos relevantes, como autor de los datos, dominio al que pertenecen, descripción, etc. con el fin de catalogarlos y facilitar
 su gestión con otras herramientas.
Es una tecnología potente y versátil, que ofrece muchas posibilidades para trabajar con datos de manera eficiente.</div>
"""

display(HTML(html_code))
# Out:
# <div style="background-color: lavender; padding: 15px; border-radius: 5px; color: indigo;">
# <strong><i>Conclusión:</i></strong><br>
# <br>
# Delta Lake es una tecnología que permite almacenar datos de manera tabular y columnar, con la capacidad de realizar operaciones de lectura y escritura de datos de manera
#  transaccional, lo que garantiza la integridad de los datos almacenados.
# Si bien realizamos operacion de lectura y escritura, además de agregar restricciones, es posible también por ejemplo realizar operaciones de eliminación de datos, consultar
#  versiones pasadas de los datos, etc.
# Las tabla delta lake permiten agregar metadatos relevantes, como autor de los datos, dominio al que pertenecen, descripción, etc. con el fin de catalogarlos y facilitar
#  su gestión con otras herramientas.
# Es una tecnología potente y versátil, que ofrece muchas posibilidades para trabajar con datos de manera eficiente.</div>
